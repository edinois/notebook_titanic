# %%
# Importando bibliotecas

import pandas as pd
import numpy as np
# %matplotlib inline
# %pylab inline
from sklearn.model_selection import RepeatedKFold
from sklearn.ensemble import RandomForestClassifier

# Ocultando as mensagens de alerta
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Criando uma função que transformará o sexo em numeral, 1 ou 0 (Female ou Male)

def transformar_sexo(valor):
    if valor == 'female':
        return 1
    else:
        return 0

# %%
# Carregando os dados de treino e teste

train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# Criando nova coluna Sex_binario no dataset de treino e teste

train['Sex_binario'] = train['Sex'].map(transformar_sexo)
test['Sex_binario'] = test['Sex'].map(transformar_sexo)

# Lendo as variaveis para treinar o modelo

variaveis = ['Sex_binario', 'Age', 'Pclass', 'SibSp', 'Parch', 'Fare']

# Criando as variáveis de entrada

X = train[variaveis].fillna(-1)
y = train['Survived']

# %%
# Verificando os tipos de dados contidos no Dataset
train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# Sex_binario      int64
# dtype: object

# %%
# Lendo o dataset

train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Sex_binario
# 0      0         A/5 21171   7.2500   NaN        S            0
# 1      0          PC 17599  71.2833   C85        C            1
# 2      0  STON/O2. 3101282   7.9250   NaN        S            1
# ...

# %%
# Utilizando a função describe

train.describe().transpose()
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
# Sex_binario  891.0    0.352413    0.477990  0.00    0.0000    0.0000    1.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292
# Sex_binario    1.0000

# %% [markdown]
# # Análise de erro

# %%
# Rodando o modelo utilizando um conjunto dos dados de validação, analisando onde o modelo está errando para 
# codificar como variável. Rodando para fazer as previsões

resultados = []
kf = RepeatedKFold(n_splits=2, n_repeats=10, random_state=10)

for linhas_treino, linhas_valid in kf.split(X):
    print("Treino:", linhas_treino.shape[0])
    print("Valid:", linhas_valid.shape[0])

    X_treino, X_valid = X.iloc[linhas_treino], X.iloc[linhas_valid]
    y_treino, y_valid = y.iloc[linhas_treino], y.iloc[linhas_valid] 
    
    modelo = RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=0)
    modelo.fit(X_treino, y_treino)

    p = modelo.predict(X_valid)

    acc = np.mean(y_valid == p)
    resultados.append(acc)
    print("Acc:", acc)
    print()
    #print(X_treino.head())
    #print()
# Out:
# Treino: 445
# Valid: 446
# Acc: 0.7869955156950673
#
# Treino: 446
# Valid: 445
# Acc: 0.7797752808988764
#
# Treino: 445
# Valid: 446
# Acc: 0.827354260089686
#
# Treino: 446
# Valid: 445
# Acc: 0.8179775280898877
#
# Treino: 445
# Valid: 446
# Acc: 0.7847533632286996
#
# Treino: 446
# Valid: 445
# Acc: 0.7842696629213484
#
# Treino: 445
# Valid: 446
# Acc: 0.8161434977578476
#
# Treino: 446
# Valid: 445
# Acc: 0.7842696629213484
#
# Treino: 445
# Valid: 446
# Acc: 0.8004484304932735
#
# Treino: 446
# Valid: 445
# Acc: 0.8
#
# Treino: 445
# Valid: 446
# Acc: 0.8183856502242153
#
# Treino: 446
# Valid: 445
# Acc: 0.802247191011236
#
# Treino: 445
# Valid: 446
# Acc: 0.8116591928251121
#
# Treino: 446
# Valid: 445
# Acc: 0.8067415730337079
#
# Treino: 445
# Valid: 446
# Acc: 0.820627802690583
#
# Treino: 446
# Valid: 445
# Acc: 0.7887640449438202
#
# Treino: 445
# Valid: 446
# Acc: 0.8385650224215246
#
# Treino: 446
# Valid: 445
# Acc: 0.8044943820224719
#
# Treino: 445
# Valid: 446
# ...

# %%
# Analisando as previsões. Inserindo as previsões em uma coluna (P)

X_valid_check = train.iloc[linhas_valid].copy()
X_valid_check['p'] = p
X_valid_check.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Sex_binario  p
# 0      0         A/5 21171   7.2500   NaN        S            0  0
# 1      0          PC 17599  71.2833   C85        C            1  1
# 2      0  STON/O2. 3101282   7.9250   NaN        S            1  0
# ...

# %%
# Verificando o tamanho do dataset
X_valid_check.shape
# Out:
# (445, 14)

# %%
# Criando um dataframe apenas com as respostas erradas feita pela previsão. Ordenando por último
# as colunas P e Survived para ter uma análise mais assertiva

erros = X_valid_check[X_valid_check['Survived'] != X_valid_check['p']]
erros = erros[['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
       'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Sex_binario', 'p', 'Survived']]
erros.head()
# Out:
#     PassengerId  Pclass                                               Name  \
# 2             3       3                             Heikkinen, Miss. Laina
# 21           22       2                              Beesley, Mr. Lawrence
# 22           23       3                        McGowan, Miss. Anna "Annie"
# 23           24       1                       Sloper, Mr. William Thompson
# 25           26       3  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
#
#        Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 2   female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 21    male  34.0      0      0            248698  13.0000   D56        S
# 22  female  15.0      0      0            330923   8.0292   NaN        Q
# 23    male  28.0      0      0            113788  35.5000    A6        S
# 25  female  38.0      1      5            347077  31.3875   NaN        S
#
#     Sex_binario  p  Survived
# 2             1  0         1
# ...

# %%
# Criando um dataset para analisar isoladamente os grupos de Mulheres e Homens, tentando facilitar a
# identificação de um padrão

mulheres = erros[erros['Sex'] == 'female']
homens = erros[erros['Sex'] == 'male']

# %%
# Analisando o dataset de mulheres, ordenando por Survived

mulheres.sort_values("Survived")
# Out:
#      PassengerId  Pclass                                               Name  \
# 888          889       3           Johnston, Miss. Catherine Helen "Carrie"
# 501          502       3                                Canavan, Miss. Mary
# 498          499       1    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 882          883       3                       Dahlberg, Miss. Gerda Ulrika
# 474          475       3                        Strandberg, Miss. Ida Sofia
# 419          420       3                          Van Impe, Miss. Catharina
# 357          358       2                          Funk, Miss. Annie Clemmer
# 254          255       3           Rosblom, Mrs. Viktor (Helena Wilhelmina)
# 503          504       3                     Laitinen, Miss. Kristina Sofia
# 654          655       3                       Hegarty, Miss. Hanora "Nora"
# 772          773       2                                  Mack, Mrs. (Mary)
# ...

# %% [markdown]
# # Notas da análise do dataset mulheres

# %% [markdown]
# - Algumas mulheres tem cabine nula;
# - Na coluna Ticket, é possível observar que alguns possuem letras, em alguns momentos possuem números sequenciais;
# - Uma outra variável interessante é a coluna Embarked, que são os 3 portos de onde as pessoas embarcaram.
# - Os nomes podem conter alguma informação importante, algumas mulheres com título em Mrs ou Miss.

# %%
# Analisando o dataset de homens, ordenando por Survived

homens.sort_values("Survived")
# Out:
#      PassengerId  Pclass                                             Name  \
# 238          239       2                  Pengelly, Mr. Frederick William
# 442          443       3                        Petterson, Mr. Johan Emil
# 422          423       3                               Zimmerman, Mr. Leo
# 373          374       1                              Ringhini, Mr. Sante
# 371          372       3                        Wiklund, Mr. Jakob Alfred
# 698          699       1                         Thayer, Mr. John Borland
# 262          263       1                                Taussig, Mr. Emil
# 231          232       3                         Larsson, Mr. Bengt Edvin
# 214          215       3                              Kiernan, Mr. Philip
# 721          722       3                        Jensen, Mr. Svend Lauritz
# 169          170       3                                    Ling, Mr. Lee
# 544          545       1                       Douglas, Mr. Walter Donald
# ...

# %% [markdown]
# # Notas da análise do dataset homens

# %% [markdown]
# - O mesmo padrão dos tickets parecido com o das mulheres.
# - A cabine de alguns é nula, em alguns aparecem 2 ou 3 valores na cabine.
# - Olhando os títulos dos homens, é possível identificar muitos com o título Mister ou Master.

# %% [markdown]
# # Novas variáveis

# %%
# Criando um indicador se a pessoa embarcou em um determinado porto

train['Embarked_S'] = (train['Embarked'] == 'S').astype(int)
train['Embarked_C'] = (train['Embarked'] == 'C').astype(int)
#train['Embarked_Q'] = (train['Embarked'] == 'Q').astype(int)

# Indicar se o campo cabine está nulo

train['Cabine_nula'] = train['Cabin'].isnull().astype(int)

# Inserindo algumas variáveis sobre os títulos informados acima, para mulheres e homens

train['Nome_contem_Miss'] = train['Name'].str.contains("Miss").astype(int)
train['Nome_contem_Mrs'] = train['Name'].str.contains("Mrs").astype(int)

train['Nome_contem_Master'] = train['Name'].str.contains("Master").astype(int)
train['Nome_contem_Col'] = train['Name'].str.contains("Col").astype(int)
train['Nome_contem_Major'] = train['Name'].str.contains("Major").astype(int)
train['Nome_contem_Mr'] = train['Name'].str.contains("Mr").astype(int)

# %%
#Verificando as variáveis

variaveis
# Out:
# ['Sex_binario', 'Age', 'Pclass', 'SibSp', 'Parch', 'Fare']

# %%
# Lista contendo as variáveis originais + as novas variáveis

variaveis = ['Sex_binario', 'Age', 'Pclass', 'SibSp', 'Parch', 'Fare', 'Embarked_S', 'Embarked_C', 'Cabine_nula',
             'Nome_contem_Miss', 'Nome_contem_Mrs',
             'Nome_contem_Master', 'Nome_contem_Col', 'Nome_contem_Major', 'Nome_contem_Mr']

# Trazendo as linhas utilizadas acima do modelo original

X = train[variaveis].fillna(-1)
y = train['Survived']

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Criando a lista resultados2 que armazenará os resultados da validação deste modelo com as novas variáveis

resultados2 = []
kf = RepeatedKFold(n_splits=2, n_repeats=10, random_state=10)

for linhas_treino, linhas_valid in kf.split(X):
    print("Treino:", linhas_treino.shape[0])
    print("Valid:", linhas_valid.shape[0])

    X_treino, X_valid = X.iloc[linhas_treino], X.iloc[linhas_valid]
    y_treino, y_valid = y.iloc[linhas_treino], y.iloc[linhas_valid]

    #modelo = RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=0)
    modelo = LogisticRegression()
    
    modelo.fit(X_treino, y_treino)

    p = modelo.predict(X_valid)

    acc = np.mean(y_valid == p)
    resultados2.append(acc)
    print("Acc:", acc)
    print()
    #print(X_treino.head())
    #print()
# Out:
# Treino: 445
# Valid: 446
# Acc: 0.7914798206278026
#
# Treino: 446
# Valid: 445
# Acc: 0.7707865168539326
#
# Treino: 445
# Valid: 446
# Acc: 0.7959641255605381
#
# Treino: 446
# Valid: 445
# Acc: 0.7797752808988764
#
# Treino: 445
# Valid: 446
# Acc: 0.7713004484304933
#
# Treino: 446
# Valid: 445
# Acc: 0.7932584269662921
#
# Treino: 445
# Valid: 446
# Acc: 0.7937219730941704
#
# Treino: 446
# Valid: 445
# Acc: 0.7955056179775281
#
# Treino: 445
# Valid: 446
# Acc: 0.7937219730941704
#
# Treino: 446
# Valid: 445
# Acc: 0.7865168539325843
#
# Treino: 445
# Valid: 446
# Acc: 0.7869955156950673
#
# Treino: 446
# Valid: 445
# Acc: 0.7910112359550562
#
# Treino: 445
# Valid: 446
# Acc: 0.804932735426009
#
# Treino: 446
# Valid: 445
# Acc: 0.7797752808988764
#
# Treino: 445
# Valid: 446
# Acc: 0.7847533632286996
#
# Treino: 446
# Valid: 445
# Acc: 0.7662921348314606
#
# Treino: 445
# Valid: 446
# Acc: 0.804932735426009
#
# Treino: 446
# Valid: 445
# Acc: 0.7752808988764045
#
# ...

# %%
# Criando um histograma para comparar o modelo novo (azul) e o modelo anterior (laranja)

pylab.hist(resultados2), pylab.hist(resultados,alpha=0.8)
# Out:
# ((array([3., 3., 1., 4., 3., 1., 1., 1., 2., 1.]),
#   array([0.80224719, 0.80610319, 0.80995919, 0.81381519, 0.81767118,
#          0.82152718, 0.82538318, 0.82923918, 0.83309518, 0.83695118,
#          0.84080717]),
#   <BarContainer object of 10 artists>),
#  (array([4., 2., 0., 4., 2., 2., 4., 0., 1., 1.]),
#   array([0.77977528, 0.78565426, 0.79153323, 0.7974122 , 0.80329118,
#          0.80917015, 0.81504913, 0.8209281 , 0.82680707, 0.83268605,
#          0.83856502]),
#   <BarContainer object of 10 artists>))

# %%
# Verificando a média

np.mean(resultados2)
# Out:
# 0.8179503199475991

# %%
# Recriando as variáveis do treino e as novas variáveis do teste para retreinar o modelo

test['Embarked_S'] = (test['Embarked'] == 'S').astype(int)
test['Embarked_C'] = (test['Embarked'] == 'C').astype(int)
#test['Embarked_Q'] = (test['Embarked'] == 'Q').astype(int)

test['Cabine_nula'] = (test['Cabin'].isnull()).astype(int)

test['Nome_contem_Miss'] = test['Name'].str.contains("Miss").astype(int)
test['Nome_contem_Mrs'] = test['Name'].str.contains("Mrs").astype(int)

test['Nome_contem_Master'] = test['Name'].str.contains("Master").astype(int)
test['Nome_contem_Col'] = test['Name'].str.contains("Col").astype(int)
test['Nome_contem_Major'] = test['Name'].str.contains("Major").astype(int)
test['Nome_contem_Mr'] = test['Name'].str.contains("Mr").astype(int)

modelo = LogisticRegression()
modelo.fit(X, y)

p = modelo.predict(test[variaveis].fillna(-1))

# %% [markdown]
# # Criando a submission

# %%
sub = pd.Series(p, index=test['PassengerId'], name='Survived')
sub.shape
# Out:
# (418,)

# %%
sub.to_csv("modelo_ajustado.csv", header=True)
